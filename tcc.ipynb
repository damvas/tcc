# %%
import pandas as pd
import os
import csv

def process_csv(file_path, chunk_size, encoding='utf-8'):
    df_list = []
    reader = pd.read_csv(file_path, sep=';', chunksize=chunk_size, encoding = encoding)

    for chunk in reader:
        df_list.append(chunk)

    df = pd.concat(df_list, ignore_index=True)
    return df

file_path = 'secex.csv'
chunk_size = 10000000

df = process_csv(file_path, chunk_size)

# %%
df.columns
# Out:
# Index(['CO_ANO', 'CO_MES', 'CO_NCM', 'CO_UNID', 'CO_PAIS', 'SG_UF_NCM',
#        'CO_VIA', 'CO_URF', 'QT_ESTAT', 'KG_LIQUIDO', 'VL_FOB'],
#       dtype='object')

# %%
dct_ncm = process_csv('dct_ncm.csv', 100, encoding='latin-1')
dct_uf = process_csv('dct_uf.csv', 100, encoding='latin-1')
dct_uf_mun = process_csv('dct_uf_mun.csv', 100, encoding='latin-1')
dct_urf = process_csv('dct_urf.csv', 100, encoding='latin-1')

# %%
dct_urf['NO_URF'] = dct_urf['NO_URF'].str.split(' - ').str[-1].str.replace('IRF ','')

# %%
cols = set(df.columns)
dct_cols = set(dct_urf.columns)
list(cols.intersection(dct_cols))
# Out:
# ['CO_URF']

# %%
df = pd.merge(df, dct_urf, how='left', on=['CO_URF'])
df = pd.merge(df, dct_ncm, how='left', on=['CO_UNID', 'CO_NCM'])
df = df.rename(columns = {'SG_UF_NCM': 'SG_UF'})
df = pd.merge(df,dct_uf,'left',['SG_UF'])

# %%
df.columns
# Out:
# Index(['CO_ANO', 'CO_MES', 'CO_NCM', 'CO_UNID', 'CO_PAIS', 'SG_UF', 'CO_VIA',
#        'CO_URF', 'QT_ESTAT', 'KG_LIQUIDO', 'VL_FOB', 'NO_URF', 'CO_SH6',
#        'CO_PPE', 'CO_PPI', 'CO_FAT_AGREG', 'CO_CUCI_ITEM', 'CO_CGCE_N3',
#        'CO_SIIT', 'CO_ISIC_CLASSE', 'CO_EXP_SUBSET', 'NO_NCM_POR',
#        'NO_NCM_ESP', 'NO_NCM_ING', 'CO_UF', 'NO_UF', 'NO_REGIAO'],
#       dtype='object')

# %%
df = pd.merge(df,dct_uf_mun,'left',['SG_UF'])

# %%
df
# Out:
#          CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF  CO_VIA   CO_URF
# 0          2022       6  85045000       11       69    MG       4   817600  \
# 1          2022       4  39219019       10      586    SP       7   917500
# 2          2022       1  44071100       16      249    SC       1   927800
# 3          2022      11  84672100       11      521    RS       1   817800
# 4          2022      10   8072000       10       23    RN       4   417901
# ...         ...     ...       ...      ...      ...   ...     ...      ...
# 1495863    2022      11  32061910       10      845    SP       7  1010252
# 1495864    2022       1  12024200       10      434    AM       1   227600
# 1495865    2022       9  18040000       21      249    BA       1   517800
# 1495866    2022       8  16010000       10       99    SC       1   927800
# 1495867    2022       8  64031900       13       69    RJ       4   817700
#
#          QT_ESTAT  KG_LIQUIDO  ...  CO_CGCE_N3  CO_SIIT  CO_ISIC_CLASSE
# 0               2        1399  ...         110   2000.0            2790  \
# 1            3914        3914  ...         240   3000.0            2220
# 2           21945     8409167  ...         240   4000.0            1610
# 3              10          25  ...         110   2000.0            2818
# 4           55356       55356  ...         323   9000.0             113
# ...           ...         ...  ...         ...      ...             ...
# 1495863       975         975  ...         240   2000.0            2011
# 1495864         4           4  ...         210   4000.0            1030
# 1495865       180      180000  ...         220   4000.0            1073
# 1495866      1820        1820  ...         324   4000.0            1010
# 1495867         1           1  ...         321   4000.0            1520
#
#          CO_EXP_SUBSET                                         NO_NCM_POR
# 0               1105.0      Outras bobinas de reatância e de auto-indução  \
# 1               1407.0  Outras chapas estratificadas, reforçadas ou co...
# 2                803.0  Madeira serrada ou fendida longitudinalmente, ...
# 3               1108.0          Furadeiras com motor elétrico incorporado
# 4               2309.0                           Mamões (papaias) frescos
# ...                ...                                                ...
# 1495863         1403.0  Pigmento constituído por mica revestida pelícu...
# 1495864         8099.0            Amendoins descascados, mesmo triturados
# 1495865          203.0                 Manteiga, gordura e óleo, de cacau
# 1495866          502.0  Enchidos e produtos semelhantes, de carne, de ...
# 1495867          401.0    Calçados para outros esportes, de couro natural
#
#                                                 NO_NCM_ESP
# 0          Las demás bobinas de reactancia (autoinducción)  \
# 1        Otras placas, etc.de otros plásticos, estratif...
# 2        Madera aserrada o desbastada longitudinalmente...
# 3                 Taladros con motor eléctrico incorporado
# 4                                          Papayas frescas
# ...                                                    ...
# 1495863  Pigmento const.por mica revest.película dióxid...
# 1495864       Cacahuetes sin cáscara, incluso quebrantados
# 1495865                  Manteca, grasa y aceite, de cacao
# 1495866  Embutidos de carne, despojos, sangre, sus prep...
# 1495867     Calzados para otros deportes, de cuero natural
#
#                                                 NO_NCM_ING  CO_UF
# 0                                          Other inductors     33  \
# 1          Other plates, etc.of other plastics, stratified     41
# 2        Wood sawn or chipped lengthwise, sliced or pee...     44
# 3                Drills with self-contained electric motor     45
# 4                                   Fresh papaws (papayas)     24
# ...                                                    ...    ...
# 1495863  Pigment consist.of mica coated w/titanium dioxide     41
# 1495864             Peanuts shelled, whether or not broken     13
# 1495865                    Butter, fat and oil, from cocoa     32
# 1495866  Sausages of meat, meat offal, blood, their foo...     44
# 1495867              Footwear for other sports, of leather     36
#
#                        NO_UF        NO_REGIAO
# 0               Minas Gerais   REGIAO SUDESTE
# 1                  São Paulo   REGIAO SUDESTE
# 2             Santa Catarina       REGIAO SUL
# 3          Rio Grande do Sul       REGIAO SUL
# 4        Rio Grande do Norte  REGIAO NORDESTE
# ...                      ...              ...
# 1495863            São Paulo   REGIAO SUDESTE
# 1495864             Amazonas     REGIAO NORTE
# 1495865                Bahia  REGIAO NORDESTE
# 1495866       Santa Catarina       REGIAO SUL
# 1495867       Rio de Janeiro   REGIAO SUDESTE
#
# [1495868 rows x 26 columns]
